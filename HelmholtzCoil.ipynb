# %%
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

I = 1
a = 2 #coil radius
b = 1  #dist of coil center from xy plane. Coils spaced by 2b then.
mu0 = 1
B0 = -3*mu0*I* a**2 * b / (2*(a**2 + b**2)**(5/2))


X = np.linspace(-a/2, a/2, 5)
Y = np.linspace(-a/2, a/2, 5)
Z = np.linspace(-1.25, 1.25, 5)

x,y,z = np.meshgrid(X, Y, Z)


# Derived for points far from the coil (close to the axis)
# So keep x, y << a
Bx = B0*x
By = B0*y
Bz = B0*-2*z


ax.quiver(x,y,z, Bx, By, Bz)
ax.set_zlabel("z", fontsize=20)
ax.set_ylabel("y", fontsize=20)
ax.set_xlabel("x", fontsize=20)
# Out:
# Text(0.5, 0, 'x')

# %%
X = np.linspace(-2, 2, 11)
Y = np.linspace(-2, 2, 11)
Z = np.linspace(-2, 2, 11)

# %%
fig, ax = plt.subplots(figsize=(6,6))

x, y = np.meshgrid(X, Y)
plt.quiver(x,y, B0*x, B0*y)

plt.xlabel("x", fontsize=20)
plt.ylabel("y", fontsize=20)
# Out:
# Text(0, 0.5, 'y')

# %%
fig, ax = plt.subplots(figsize=(6,6))

x, z = np.meshgrid(X, Z)
plt.quiver(x,z, B0*x, B0*-2*z)

plt.xlabel("x", fontsize=20)
plt.ylabel("z", fontsize=20)

xarr = np.linspace(-2, 2, 1000)
zarr = xarr
plt.plot(xarr, zarr)

# %%
fig, ax = plt.subplots(figsize=(6,6))

y, z = np.meshgrid(Y, Z)
plt.quiver(y,z, B0*y, B0*-2*z)

plt.xlabel("y", fontsize=20)
plt.ylabel("z", fontsize=20)
# Out:
# Text(0, 0.5, 'z')
